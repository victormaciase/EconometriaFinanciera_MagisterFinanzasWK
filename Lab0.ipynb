# %% [markdown]
# <a href="https://colab.research.google.com/github/victormaciase/EconometriaFinanciera_MagisterFinanzasWK/blob/main/Lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %% [markdown]
# # Tipos de variables

# %% [markdown]
# ## Variables cuantitativas

# %% [markdown]
# *   **_Variables discretas_** son a menudo representadas por **integers**
# *   **_Variables continuas_** son a usualmente representadas por **floats**

# %% [markdown]
# Algunos ejemplos son:

# %%
type(5)
# Out:
# int

# %%
type(3.6)
# Out:
# float

# %%
type(3/8)
# Out:
# float

# %% [markdown]
# ## Variables categóricas

# %% [markdown]
# *   **_Variables categóricas ordinales_** son a menudo representadas por **integers**
# *   **_Variables categóricas nominales_** pueden ser representadas por números **integers** o **strings**

# %%
type("AAPL")  # string
# Out:
# str

# %% [markdown]
# type(12>7)

# %%
type(9>7)   # boolean
# Out:
# bool

# %%
9 > 7
# Out:
# True

# %%
4**2 == -4**2
# Out:
# False

# %% [markdown]
# # Operaciones aritméticas

# %%
3**4    # exponenciación
# Out:
# 81

# %% [markdown]
# $log_{10}1000$

# %%
math.log10(1000)   # logaritmo de 1000 en base 10
# Out:
# 3.0

# %% [markdown]
# Otra forma de calcularlo es:

# %%
math.log(1000, 10)
# Out:
# 2.9999999999999996

# %% [markdown]
# $log_232$

# %%
math.log(32, 2)
# Out:
# 5.0

# %% [markdown]
# ln 9

# %%
math.log(9)
# Out:
# 2.1972245773362196
