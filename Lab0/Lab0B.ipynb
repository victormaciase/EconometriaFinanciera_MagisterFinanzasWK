# %% [markdown]
# <a href="https://colab.research.google.com/github/victormaciase/EconometriaFinanciera_MagisterFinanzasWK/blob/main/Lab0/Lab0B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ¿Qué es una librería en Python?
#
# Una librería (o módulo) es una colección de funciones, herramientas y códigos preescritos que extienden las capacidades básicas de Python. En lugar de programar todo desde cero para resolver un problema, puedes usar una librería para ahorrar tiempo y esfuerzo.
#
# Existen dos tipos principales:
#
# - **Estándar:** Vienen incluidas por defecto en Python (como *math* o *random*).
#
# - **Externas:** Desarrolladas por la comunidad (como *pandas* para analizar datos o *matplotlib* para hacer gráficos) que se instalan fácilmente.
#
# # ¿Cómo se usan?
# Para usar una librería en tu código, después de instalada solo debes importarla al inicio de tu archivo usando la palabra clave *import*.

# %%
# 1. Importas la librería (puedes darle un alias corto con 'as')
import numpy as np

# 2. Usas sus funciones predefinidas
datos = [4, 2, 1, 9, 8]
promedio = np.mean(datos)

print(promedio) # Devuelve 4.8 sin que hayas tenido que programar la fórmula matemática
# Out:
# 4.8

# %% [markdown]
# Si aplicaras directamente la fórmula:
# $$\overline x=\frac{\sum_{i=1}^n x_i}{n}$$
#
# se tiene:

# %%
sum(datos)/len(datos)
# Out:
# 4.8

# %% [markdown]
# Y para calcular la desviación estándar:

# %%
np.std(datos, ddof=1)
# Out:
# np.float64(3.5637059362410923)

# %% [markdown]
# Aplicando directamente la fórmula:
#
# $$s=\sqrt{\frac{\sum_{i=1}^n(x_i-\overline x)^2}{n-1}}$$
#
# se tiene:

# %%
np.sqrt(sum((datos-np.mean(datos))**2)/(len(datos)-1))
# Out:
# np.float64(3.5637059362410923)
